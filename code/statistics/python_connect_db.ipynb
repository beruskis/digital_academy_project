# %% [markdown]
# ## Python Database Connection
# Thanks to the connection with our database, we can work on statistics directly on our datasets in both dbo and raw schema.

# %%
# Import pandas library for working with data as tables
import pandas as pd
# Import create_engine to set up a database connection
from sqlalchemy import create_engine, text

# %%
# Set up the connection to the database
# This tells Python where the database is and login details
engine = create_engine(
    "mssql+pyodbc://p_forestgdp:h0sPJ40jfN3$@db.czechitas.online,3033/db_forestgdp"
    "?driver=ODBC+Driver+17+for+SQL+Server&TrustServerCertificate=yes"
)

# %%
# Connect to the database and load one of the tables into a dataframe (as an example -> dim_country with it's first 5 rows and column names to see what is inside)
with engine.connect() as conn:
    df = pd.read_sql(text("SELECT * FROM dbo.dim_country"), conn)

print(df.head())            # shows first 5 rows
print(df.columns.tolist())  # shows all column names
# Out:
#                 country_code           country_name  \
# 0                        ABW                  Aruba
# 1                        AFG            Afghanistan
# 2                AGG_England                England
# 3    AGG_European_Union_(27)    European Union (27)
# 4  AGG_High-income_countries  High-income countries
#
#                       region income_group                 subregion  \
# 0  Latin America & Caribbean  High income                 Caribbean
# 1                 South Asia   Low income  Western and Central Asia
# 2                        NaN          NaN                       NaN
# 3                        NaN          NaN                       NaN
# 4                        NaN          NaN                       NaN
#
#    land_area_km2
# 0          180.0
# 1       652230.0
# 2            NaN
# 3            NaN
# 4            NaN
# ['country_code', 'country_name', 'region', 'income_group', 'subregion', 'land_area_km2']

# %%
#When working with 2 datasets at the same time, both need to be loaded and merged as below:
with engine.connect() as conn:
    df_forest = pd.read_sql(text("SELECT * FROM dbo.fact_forest"), conn)
    df_gdp    = pd.read_sql(text("SELECT * FROM dbo.fact_gdp"), conn)

# Merge on a common column, e.g. country_code
df = pd.merge(df_forest, df_gdp, on=["country_code", "year"])

# %%
print(df.head(50))
# Out:
#     id_x country_code  year  forest_pct  forest_change_pct  forest_area_km2  \
# 0      1          AFG  1990        1.85                NaN        12066.255
# 1      2          AFG  1991        1.85               0.00        12066.255
# 2      3          AFG  1992        1.85               0.00        12066.255
# 3      4          AFG  1993        1.85               0.00        12066.255
# 4      5          AFG  1994        1.85               0.00        12066.255
# 5      6          AFG  1995        1.85               0.00        12066.255
# 6      7          AFG  1996        1.85               0.00        12066.255
# 7      8          AFG  1997        1.85               0.00        12066.255
# 8      9          AFG  1998        1.85               0.00        12066.255
# 9     10          AFG  1999        1.85               0.00        12066.255
# 10    11          AFG  2000        1.85               0.00        12066.255
# ...
