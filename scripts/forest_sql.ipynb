# %%
import pandas as pd
from sqlalchemy import create_engine
import pyodbc
from mssql_python import connect

# %%
df_forest = pd.read_csv("MAIN_1990-2025forest-area-as-share-of-land-area.csv")

# %%
server      = 'db.czechitas.online:3033'
database    = 'db_forestgdp'
table_name  = 'Forest_year'
schema      = 'dbo'
username = '/p_forestgdp/'
password = '/h0sPJ40jfN3$/'

print(f"Načteno {len(df_forest)} řádků, {len(df_forest.columns)} sloupců")
print(df_forest.head())
# --- PŘIPOJENÍ K SQL SERVERU ---
connection_string = f"mssql+pyodbc://{username}:{password}@{server}/{database}?driver=ODBC+Driver+18+for+SQL+Server&TrustServerCertificate=yes"
engine = create_engine(connection_string)
# --- IMPORT DO SQL ---
df_forest.to_sql(
    name        = table_name,
    con         = engine,
    schema      = schema,
    if_exists   = 'append',
    index       = False
)
print("Import dokončen!")
# Out:
# Načteno 7970 řádků, 5 sloupců
#        Country Code  Year  Forest_percentage Notes
# 0  Afghanistan  AFG  1990           1.854315   NaN
# 1  Afghanistan  AFG  1991           1.854315   NaN
# 2  Afghanistan  AFG  1992           1.854315   NaN
# 3  Afghanistan  AFG  1993           1.854315   NaN
# 4  Afghanistan  AFG  1994           1.854315   NaN
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# ...
