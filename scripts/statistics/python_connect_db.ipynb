# %%
# Import pandas library for working with data as tables
import pandas as pd
# Import create_engine to set up a database connection
from sqlalchemy import create_engine

# %%
# Set up the connection to the database
# This tells Python where the database is and hlogin details
engine = create_engine(
    "mssql+pyodbc://p_forestgdp:h0sPJ40jfN3$@db.czechitas.online,3033/db_forestgdp"
    "?driver=ODBC+Driver+17+for+SQL+Server&TrustServerCertificate=yes"
)

# %%
# Connect to the database and load one of the tables into a dataframe (as an example -> dim_country with it's first 5 rows and column names to see what is inside)
with engine.connect() as conn:
    df = pd.read_sql(text("SELECT * FROM dbo.dim_country"), conn)

print(df.head())            # shows first 5 rows
print(df.columns.tolist())  # shows all column names
# Out:
#                 country_code           country_name  \
# 0                        ABW                  Aruba
# 1                        AFG            Afghanistan
# 2                AGG_England                England
# 3    AGG_European_Union_(27)    European Union (27)
# 4  AGG_High-income_countries  High-income countries
#
#                       region income_group
# 0  Latin America & Caribbean  High income
# 1                 South Asia   Low income
# 2                        NaN          NaN
# 3                        NaN          NaN
# 4                        NaN          NaN
# ['country_code', 'country_name', 'region', 'income_group']

# %%
#When working with 2 datasets at the same time, both need to be loaded and merged as below:
with engine.connect() as conn:
    df_forest = pd.read_sql(text("SELECT * FROM dbo.fact_forest"), conn)
    df_gdp    = pd.read_sql(text("SELECT * FROM dbo.fact_gdp"), conn)

# Merge on a common column, e.g. country_code
df = pd.merge(df_forest, df_gdp, on=["country_code"])

# %%
print(df.head(50))
# Out:
#     id_x country_code  year_x  forest_pct  id_y  year_y  gdp_per_capita
# 0      1          AFG    1990        1.85     1    1990             NaN
# 1      1          AFG    1990        1.85     2    1991             NaN
# 2      1          AFG    1990        1.85     3    1992             NaN
# 3      1          AFG    1990        1.85     4    1993             NaN
# 4      1          AFG    1990        1.85     5    1994             NaN
# 5      1          AFG    1990        1.85     6    1995             NaN
# 6      1          AFG    1990        1.85     7    1996             NaN
# 7      1          AFG    1990        1.85     8    1997             NaN
# 8      1          AFG    1990        1.85     9    1998             NaN
# 9      1          AFG    1990        1.85    10    1999             NaN
# 10     1          AFG    1990        1.85    11    2000          174.93
# 11     1          AFG    1990        1.85    12    2001          138.71
# 12     1          AFG    1990        1.85    13    2002          178.95
# 13     1          AFG    1990        1.85    14    2003          198.87
# 14     1          AFG    1990        1.85    15    2004          221.76
# 15     1          AFG    1990        1.85    16    2005          254.18
# 16     1          AFG    1990        1.85    17    2006          274.22
# 17     1          AFG    1990        1.85    18    2007          376.22
# 18     1          AFG    1990        1.85    19    2008          381.73
# 19     1          AFG    1990        1.85    20    2009          452.05
# 20     1          AFG    1990        1.85    21    2010          560.62
# 21     1          AFG    1990        1.85    22    2011          606.69
# 22     1          AFG    1990        1.85    23    2012          651.42
# 23     1          AFG    1990        1.85    24    2013          637.09
# 24     1          AFG    1990        1.85    25    2014          625.05
# 25     1          AFG    1990        1.85    26    2015          565.57
# 26     1          AFG    1990        1.85    27    2016          522.08
# 27     1          AFG    1990        1.85    28    2017          525.47
# 28     1          AFG    1990        1.85    29    2018          491.34
# 29     1          AFG    1990        1.85    30    2019          496.60
# 30     1          AFG    1990        1.85    31    2020          510.79
# 31     1          AFG    1990        1.85    32    2021          356.50
# 32     1          AFG    1990        1.85    33    2022          357.26
# 33     1          AFG    1990        1.85    34    2023          413.76
# 34     1          AFG    1990        1.85    35    2024             NaN
# 35     2          AFG    1991        1.85     1    1990             NaN
# 36     2          AFG    1991        1.85     2    1991             NaN
# 37     2          AFG    1991        1.85     3    1992             NaN
# 38     2          AFG    1991        1.85     4    1993             NaN
# 39     2          AFG    1991        1.85     5    1994             NaN
# 40     2          AFG    1991        1.85     6    1995             NaN
# 41     2          AFG    1991        1.85     7    1996             NaN
# 42     2          AFG    1991        1.85     8    1997             NaN
# 43     2          AFG    1991        1.85     9    1998             NaN
# 44     2          AFG    1991        1.85    10    1999             NaN
# 45     2          AFG    1991        1.85    11    2000          174.93
# 46     2          AFG    1991        1.85    12    2001          138.71
# 47     2          AFG    1991        1.85    13    2002          178.95
# 48     2          AFG    1991        1.85    14    2003          198.87
# 49     2          AFG    1991        1.85    15    2004          221.76
