# %%
import pandas as pd

# %%
df_forest = pd.read_csv("MAIN_1990-2025forest-area-as-share-of-land-area.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_forest = pd.read_csv("MAIN_1990-2025forest-area-as-share-of-land-area.csv")
#
# NameError: name 'pd' is not defined

# %%
display(df_forest)
display(df_gdp)
# Out:
#            Entity Code  Year  Share of land covered by forest  \
# 0     Afghanistan  AFG  1990                         1.854315
# 1     Afghanistan  AFG  1991                         1.854315
# 2     Afghanistan  AFG  1992                         1.854315
# 3     Afghanistan  AFG  1993                         1.854315
# 4     Afghanistan  AFG  1994                         1.854315
# ...           ...  ...   ...                              ...
# 7965     Zimbabwe  ZWE  2021                        36.132893
# 7966     Zimbabwe  ZWE  2022                        35.995890
# 7967     Zimbabwe  ZWE  2023                        35.858887
# 7968     Zimbabwe  ZWE  2024                        35.721880
# 7969     Zimbabwe  ZWE  2025                        35.584877
#
#      Share of land covered by forest (Annotations)
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# ...

# %%
print("Rows_count:", df_forest.shape[0])
print("Columns_count:", df_forest.shape[1])
# Out:
# Rows_count: 7970
# Columns_count: 5

# %%
print("Column_names:")
print(df_forest.columns.tolist())
# Out:
# Column_names:
# ['Entity', 'Code', 'Year', 'Share of land covered by forest', 'Share of land covered by forest (Annotations)']

# %%
print("Data_types:")
print(df_forest.dtypes)
# Out:
# Data_types:
# Entity                                               str
# Code                                                 str
# Year                                               int64
# Share of land covered by forest                  float64
# Share of land covered by forest (Annotations)        str
# dtype: object
