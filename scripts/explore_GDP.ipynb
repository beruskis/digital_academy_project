# %%
import pandas as pd

# %%
df_gdp = pd.read_csv("1960-2024_GDP_USD.csv", skiprows=4)

# %%
display(df_gdp)
# Out:
#                     Country Name Country Code                Indicator Name  \
# 0                          Aruba          ABW  GDP per capita (current US$)
# 1    Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                    Afghanistan          AFG  GDP per capita (current US$)
# 3     Africa Western and Central          AFW  GDP per capita (current US$)
# 4                         Angola          AGO  GDP per capita (current US$)
# ..                           ...          ...                           ...
# 261                       Kosovo          XKX  GDP per capita (current US$)
# 262                  Yemen, Rep.          YEM  GDP per capita (current US$)
# 263                 South Africa          ZAF  GDP per capita (current US$)
# 264                       Zambia          ZMB  GDP per capita (current US$)
# 265                     Zimbabwe          ZWE  GDP per capita (current US$)
#
# ...

# %%
print("Rows_count:", df_gdp.shape[0])
print("Columns_count:", df_gdp.shape[1])
# Out:
# Rows_count: 266
# Columns_count: 71

# %%
print("Column_names:")
print(df_gdp.columns.tolist())
# Out:
# Column_names:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025', 'Unnamed: 70']

# %%
print("Data_types:")
print(df_gdp.dtypes)
# Out:
# Data_types:
# Country Name          str
# Country Code          str
# Indicator Name        str
# Indicator Code        str
# 1960              float64
#                    ...
# 2022              float64
# 2023              float64
# 2024              float64
# 2025              float64
# Unnamed: 70       float64
# Length: 71, dtype: object
